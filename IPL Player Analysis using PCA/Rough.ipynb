# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
players2013=pd.read_csv("IPL(2013-19).csv")

# %%
players2012=pd.read_csv("IPL(2012-19).csv")

# %%
players2013
# Out:
#           Player's Name  Sl.No Team From  Run  Ball Strike Rate  Four  Six  \
# 0              MS Dhoni    149  CSK  IND  398   238       167.2    29   20
# 1          Suresh Raina    236  CSK  IND  548   364       150.5    50   18
# 2        Faf du Plessis     79  CSK   SA    0     0           -     0    0
# 3       Ravindra Jadeja    187  CSK  IND  201   133       151.1    17    6
# 4          Dwayne Bravo     75  CSK   WI  106    90       117.8     8    3
# 5          Shane Watson    214   RR  AUS  543   380       142.9    59   22
# 6          Kedar Jadhav    114   DD  IND  152   124       122.6     8    5
# 7         Ambati Rayudu     19   MI  IND  228   195       116.9    18    4
# 8       Harbhajan Singh     86   MI  IND  102    71       143.7     9    5
# 9          Mohit Sharma    146  CSK  IND    0     3           0     0    0
# 10         Rohit Sharma    192   MI  IND  536   404       132.7    35   28
# ...

# %%
players2018=pd.read_csv("IPL(2018-19).csv")

# %%
players2018["Type"].fillna("NAN",inplace=True)

# %%
players2013
# Out:
#           Player's Name  Sl.No Team From  Run  Ball Strike Rate  Four  Six  \
# 0              MS Dhoni    149  CSK  IND  398   238       167.2    29   20
# 1          Suresh Raina    236  CSK  IND  548   364       150.5    50   18
# 2        Faf du Plessis     79  CSK   SA    0     0           -     0    0
# 3       Ravindra Jadeja    187  CSK  IND  201   133       151.1    17    6
# 4          Dwayne Bravo     75  CSK   WI  106    90       117.8     8    3
# 5          Shane Watson    214   RR  AUS  543   380       142.9    59   22
# 6          Kedar Jadhav    114   DD  IND  152   124       122.6     8    5
# 7         Ambati Rayudu     19   MI  IND  228   195       116.9    18    4
# 8       Harbhajan Singh     86   MI  IND  102    71       143.7     9    5
# 9          Mohit Sharma    146  CSK  IND    0     3           0     0    0
# 10         Rohit Sharma    192   MI  IND  536   404       132.7    35   28
# ...

# %%
bat2012=players2012[players2012["Type"]=="BAT"]

# %%
bowl2012=players2012[players2012["Type"]=="Bowl"]

# %%
AR2012=players2012[players2012["Type"]=="AR"]

# %%
WK2012=players2012[players2012["Type"]=="WK"]

# %%
bat2013=players2013[players2013["Type"]=="BAT"]

# %%
bowl2013=players2013[players2013["Type"]=="Bowl"]

# %%
AR2013=players2013[players2013["Type"]=="AR"]

# %%
WK2013=players2013[players2013["Type"]=="WK"]

# %%
bat2018=players2018[players2018["Type"]=="BAT"]

# %%
bowl2018=players2018[players2018["Type"]=="Bowl"]

# %%
AR2018=players2018[players2018["Type"]=="AR"]

# %%
WK2018=players2018[players2018["Type"]=="WK"]

# %%
players2017=pd.read_csv("IPL(2017-19).csv")

# %%
players2017.isna().sum()
# Out:
# Player's Name         0
# Sl.no                 0
# Team                  0
# From                  1
# Run                   0
# Ball                  0
# Strike Rate           0
# Four                  0
# Six                   0
# Highest Run Scored    0
# Balls Bowled          0
# Runs Conceded         0
# Economy               0
# Wickets               0
# Ct_St                 0
# Run Outs              0
# Matches Played        0
# Age                   1
# Type                  1
# dtype: int64

# %%
players2017["Type"].fillna("AR",inplace=True)

# %%
bat2017=players2017[players2017["Type"]=="BAT"]

# %%
bowl2017=players2017[players2017["Type"]=="Bowl"]

# %%
AR2017=players2017[players2017["Type"]=="AR"]

# %%
WK2017=players2017[players2017["Type"]=="WK"]

# %%
AR2013
# Out:
#           Player's Name  Sl.No Team From  Run  Ball Strike Rate  Four  Six  \
# 3       Ravindra Jadeja    187  CSK  IND  201   133       151.1    17    6
# 4          Dwayne Bravo     75  CSK   WI  106    90       117.8     8    3
# 5          Shane Watson    214   RR  AUS  543   380       142.9    59   22
# 15       Kieron Pollard    117   MI   WI  360   249       144.6    20   26
# 17         Yuvraj Singh    274  PWI  IND  238   190       125.3    14   15
# 21        Andre Russell     24   DD   WI   11    14        78.6     0    0
# 26         Chris Morris     57  CSK  IND   14    15        93.3     0    0
# 28        Vijay Shankar    250  CSK  IND    0     0           -     0    0
# 31           Axar Patel     15   MI  IND    0     0           -     0    0
# 33         Jalaj Saxena     98   MI  IND    0     0           -     0    0
# 38         Yusuf Pathan    273  KKR  IND  332   240       138.3    30   14
# ...

# %%
AR2013["wickettaking2013"]=AR2013["BallsBowled"]/AR2013["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2013["consistency2013"]=AR2013["RunsConceded"]/AR2013["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2013["HardHitting2013"]=(4*AR2013["Four"]+6*AR2013["Six"])/AR2013["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2013["FastScoring2012"]=AR2013["Run"]/AR2013["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2013["Running2012"]=(AR2013["Run"]-(4*AR2013["Four"]+6*AR2013["Six"]))/(AR2013["Ball"]-(AR2013["Four"]+AR2013["Six"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2012["wickettaking2012"]=AR2012["Balls Bowled"]/AR2012["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2012["consistency2012"]=AR2012["Runs Concede"]/AR2012["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2012["HardHitting2012"]=(4*AR2012["Four"]+6*AR2012["Six"])/AR2012["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2012["FastScoring2012"]=AR2012["Run"]/AR2012["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2012["Running2012"]=(AR2012["Run"]-(4*AR2012["Four"]+6*AR2012["Six"]))/(AR2012["Ball"]-(AR2012["Four"]+AR2012["Six"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2013["wickettaking2013"]=bowl2013["BallsBowled"]/bowl2013["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2013["consistency2013"]=bowl2013["RunsConceded"]/bowl2013["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2012["wickettaking2012"]=bowl2012["Balls Bowled"]/bowl2012["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2012["consistency2012"]=bowl2012["Runs Concede"]/bowl2012["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2013["HardHitting2013"]=(4*bat2013["Four"]+6*bat2013["Six"])/bat2013["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2013["FastScoring2017"]=bat2013["Run"]/bat2013["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2013["Running2017"]=(bat2013["Run"]-(4*bat2013["Four"]+6*bat2013["Six"]))/(bat2013["Ball"]-(bat2013["Four"]+bat2013["Six"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2012["HardHitting2012"]=(4*bat2012["Four"]+6*bat2012["Six"])/bat2012["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2012["FastScoring2012"]=bat2012["Run"]/bat2012["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2012["Running2012"]=(bat2012["Run"]-(4*bat2012["Four"]+6*bat2012["Six"]))/(bat2012["Ball"]-(bat2012["Four"]+bat2012["Six"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2017["HardHitting2017"]=(4*AR2017["Four"]+6*AR2017["Six"])/AR2017["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2017["FastScoring2017"]=AR2017["Run"]/AR2017["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2017["Running2017"]=(AR2017["Run"]-(4*AR2017["Four"]+6*AR2017["Six"]))/(AR2017["Ball"]-(AR2017["Four"]+AR2017["Six"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2017["wickettaking2017"]=AR2017["Balls Bowled"]/AR2017["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2017["consistency2017"]=AR2017["Runs Conceded"]/AR2017["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2018["HardHitting2018"]=(4*AR2018["4\'s"]+6*AR2018["6\'s"])/AR2018["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2018["FastScoring2018"]=AR2018["Run"]/AR2018["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2018["Running2018"]=(AR2018["Run"]-(4*AR2018["4\'s"]+6*AR2018["6\'s"]))/(AR2018["Ball"]-(AR2018["4\'s"]+AR2018["6\'s"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2018["wickettaking2018"]=AR2018["Balls  Bowled"]/AR2018["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AR2018["consistency2018"]=AR2018["Runs Scored"]/AR2018["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2012
# Out:
#         Player's Name  Sl No Team From  Balls Bowled  Runs Concede  \
# 1       Deepak Chahar     76   RR  IND             0             0
# 6     Harbhajan Singh    100   MI  IND           324           384
# 10     Lasith Malinga    136   MI   SL           333           350
# 15      Piyush Chawla    180  KXI  IND           342           419
# 16      Kuldeep Yadav    132   MI  IND             0             0
# 17        Amit Mishra     25   DC  IND           282           377
# 18      Harshal Patel    104  RCB  IND           246           340
# 19      Ishant Sharma    110   DC  IND             0             0
# 21  Bhuvneshwar Kumar     49  PWI  IND           234           281
# 25    Dhawal Kulkarni     77   MI  IND            48            64
# 26     Jaydev Unadkat    118  KKR  IND            18            32
#
#         Economy  Wickets  Ct_St  Matches Played  Age  Type  wickettaking2012
# 1             -        0      0               0   19  Bowl               NaN
# ...

# %%
bat2013.drop(["Balls Bowled","Economy","Runs Concede","Wickets"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bat2012.drop(["Balls Bowled","Economy","Runs Concede","Wickets"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bat2017.drop(["Balls Bowled","Economy","Runs Conceded","Wickets"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bowl2012
# Out:
#         Player's Name  Sl No Team From  Run  Ball  Strike Rate  Four  Six  \
# 1       Deepak Chahar     76   RR  IND    0     0            -     0    0
# 6     Harbhajan Singh    100   MI  IND  108    80          135    14    3
# 10     Lasith Malinga    136   MI   SL   55    53  103.7735849     4    3
# 15      Piyush Chawla    180  KXI  IND  106    88  120.4545455     9    4
# 16      Kuldeep Yadav    132   MI  IND    0     4            0     0    0
# 17        Amit Mishra     25   DC  IND   16    20           80     1    0
# 18      Harshal Patel    104  RCB  IND   15    15          100     1    0
# 19      Ishant Sharma    110   DC  IND    0     0            -     0    0
# 21  Bhuvneshwar Kumar     49  PWI  IND   40    40          100     4    0
# 25    Dhawal Kulkarni     77   MI  IND   10     5          200     2    0
# 26     Jaydev Unadkat    118  KKR  IND    0     0            -     0    0
#
#     Balls Bowled  Runs Concede      Economy  Wickets  Ct_St  Matches Played  \
# ...

# %%
bowl2012.drop(["Run","Ball","Strike Rate","Four","Six"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bowl2013.drop(["Run","Ball","Strike Rate","Four","Six"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bowl2018.drop(["Run","Ball","Strike Rate","4's","6's","Highest Run Scored","Run Outs"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bowl2017.drop(["Run","Ball","Strike Rate","Four","Six","Highest Run Scored","Run Outs"],axis=1,inplace=True)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bat2018["HardHitting2018"]=(4*bat2018["4\'s"]+6*bat2018["6\'s"])/bat2018["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2018["FastScoring2018"]=bat2018["Run"]/bat2018["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2018["Running2018"]=(bat2018["Run"]-(4*bat2018["4\'s"]+6*bat2018["6\'s"]))/(bat2018["Ball"]-(bat2018["4\'s"]+bat2018["6\'s"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2018["wickettaking2018"]=bowl2018["Balls  Bowled"]/bowl2018["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2013
# Out:
#           Player's Name  Sl.No Team From  Run  Ball Strike Rate  Four  Six  \
# 8       Harbhajan Singh     86   MI  IND  102    71       143.7     9    5
# 9          Mohit Sharma    146  CSK  IND    0     3           0     0    0
# 11       Jasprit Bumrah    104   MI  IND    0     0           -     0    0
# 16       Lasith Malinga    124   MI   SL    9    16        56.3     1    0
# 22         Sunil Narine    233  KKR   WI   21    19       110.5     0    2
# 23        Piyush Chawla    171  KXI  IND   64    57       112.3     5    3
# 24          Amit Mishra     20   SH  IND   89    96        92.7     9    0
# 25        Harshal Patel     90  BRC  IND    0     0           -     0    0
# 29       Shahbaz Nadeem    211   DD  IND   14    27        51.9     1    0
# 32        Ishant Sharma     94   SH  IND    0     0           -     0    0
# 34    Bhuvneshwar Kumar     45  PWI  IND   52    71        73.2     3    1
# ...

# %%
bowl2017["wickettaking2017"]=bowl2017["Balls Bowled"]/bowl2017["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2018["consistency2018"]=bowl2018["Runs Scored"]/bowl2018["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bowl2017["consistency2017"]=bowl2017["Runs Conceded"]/bowl2017["Wickets"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2017["HardHitting2017"]=(4*bat2017["Four"]+6*bat2017["Six"])/bat2017["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2017["FastScoring2017"]=bat2017["Run"]/bat2017["Ball"]
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat2017["Running2017"]=(bat2017["Run"]-(4*bat2017["Four"]+6*bat2017["Six"]))/(bat2017["Ball"]-(bat2017["Four"]+bat2017["Six"]))
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bat20172018=pd.merge(bat2018,bat2017,how='outer',on=["Player's Name"])

# %%
bat2017
# Out:
#         Player's Name  Sl.no Team From  Run  Ball Strike Rate  Four   Six  \
# 1        Suresh Raina    189   GL  IND  442   307         144    42  13.0
# 4      Faf du Plessis     60  RPS   SA    8     7       114.3     1   0.0
# 10       Kedar Jadhav     90  RCB  IND  267   186       143.5    25  10.0
# 11      Ambati Rayudu      9   MI  IND   91    78       116.7     7   3.0
# 15       Rohit Sharma    156   MI  IND  333   273         122    31   9.0
# 20   Suryakumar Yadav    190  KKR  IND  105    88       119.3     8   3.0
# 22       Siddhesh Lad    184   MI  IND    0     0           -     0   0.0
# 34         Chris Lynn     41  KKR  AUS  295   163         181    25  19.0
# 38        Nitish Rana    131   MI  IND  333   264       126.1    24  17.0
# 39        Rinku Singh    152  KXI  IND    0     0           -     0   0.0
# 43       Shreyas Iyer    181   DD  IND  338   243       139.1    36  10.0
# 53     Shikhar Dhawan    178   SH  IND  479   376       127.4    53   9.0
# ...

# %%
bat2018_2=bat2017[bat2017["Matches Played"]!=0]

# %%
bat2018_22=bat2018_2.drop(["Player's Name","Sl.no","Team","From","Ct_St","Age","Type"],axis=1)

# %%
bat2017
# Out:
#         Player's Name  Sl.no Team From  Run  Ball Strike Rate  Four   Six  \
# 1        Suresh Raina    189   GL  IND  442   307         144    42  13.0
# 4      Faf du Plessis     60  RPS   SA    8     7       114.3     1   0.0
# 10       Kedar Jadhav     90  RCB  IND  267   186       143.5    25  10.0
# 11      Ambati Rayudu      9   MI  IND   91    78       116.7     7   3.0
# 15       Rohit Sharma    156   MI  IND  333   273         122    31   9.0
# 20   Suryakumar Yadav    190  KKR  IND  105    88       119.3     8   3.0
# 22       Siddhesh Lad    184   MI  IND    0     0           -     0   0.0
# 34         Chris Lynn     41  KKR  AUS  295   163         181    25  19.0
# 38        Nitish Rana    131   MI  IND  333   264       126.1    24  17.0
# 39        Rinku Singh    152  KXI  IND    0     0           -     0   0.0
# 43       Shreyas Iyer    181   DD  IND  338   243       139.1    36  10.0
# 53     Shikhar Dhawan    178   SH  IND  479   376       127.4    53   9.0
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca5 = PCA(n_components=2)

# %%
pca5.fit(bat2018_22)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
lol5=pca5.transform(bat2018_22)

# %%
lol2=lol

# %%
from pandas import DataFrame

# %%
data=pd.DataFrame(lol5)

# %%
data["Name"]=bat2018_2["Player\'s Name"]

# %%
data.reset_index(drop=True,inplace=True)

# %%
haha=bat2018_2

# %%
haha.reset_index(drop=True,inplace=True)

# %%
haha
# Out:
#        Player's Name  Sl.no Team From  Run  Ball Strike Rate  Four   Six  \
# 0       Suresh Raina    189   GL  IND  442   307         144    42  13.0
# 1     Faf du Plessis     60  RPS   SA    8     7       114.3     1   0.0
# 2       Kedar Jadhav     90  RCB  IND  267   186       143.5    25  10.0
# 3      Ambati Rayudu      9   MI  IND   91    78       116.7     7   3.0
# 4       Rohit Sharma    156   MI  IND  333   273         122    31   9.0
# 5   Suryakumar Yadav    190  KKR  IND  105    88       119.3     8   3.0
# 6         Chris Lynn     41  KKR  AUS  295   163         181    25  19.0
# 7        Nitish Rana    131   MI  IND  333   264       126.1    24  17.0
# 8       Shreyas Iyer    181   DD  IND  338   243       139.1    36  10.0
# 9     Shikhar Dhawan    178   SH  IND  479   376       127.4    53   9.0
# 10      Deepak Hooda     52   SH  IND   78    52         150     5   4.0
# 11     Manish Pandey    103  KKR  IND  396   308       128.6    28  12.0
# ...

# %%
bat2018_2["Player\'s Name"]
# Out:
# 0         Suresh Raina
# 1       Faf du Plessis
# 2         Kedar Jadhav
# 3        Ambati Rayudu
# 4         Rohit Sharma
# 5     Suryakumar Yadav
# 6           Chris Lynn
# 7          Nitish Rana
# 8         Shreyas Iyer
# 9       Shikhar Dhawan
# 10        Deepak Hooda
# 11       Manish Pandey
# 12        Yusuf Pathan
# 13        David Warner
# 14     Kane Williamson
# 15      Martin Guptill
# 16      Ajinkya Rahane
# 17         Manan Vohra
# 18         Chris Gayle
# 19      Mayank Agarwal
# 20          Karun Nair
# 21        David Miller
# 22         Virat Kohli
# 23      AB de Villiers
# 24       Mandeep Singh
# Name: Player's Name, dtype: object

# %%
data.head()
# Out:
#             0          1            name
# 0  226.158131  12.264081    Suresh Raina
# 1 -308.927000 -13.399977  Faf du Plessis
# 2   12.549889  16.995767    Kedar Jadhav
# 3 -194.252404   3.276929   Ambati Rayudu
# 4  115.819742 -23.920052    Rohit Sharma

# %%
data["name"]=haha["Player\'s Name"]

# %%
data.drop("Name",axis=1,inplace=True)

# %%
data.to_csv("2017BatRank.csv")

# %%
AR2013
# Out:
#           Player's Name  Sl.No Team From  Run  Ball Strike Rate  Four  Six  \
# 3       Ravindra Jadeja    187  CSK  IND  201   133       151.1    17    6
# 4          Dwayne Bravo     75  CSK   WI  106    90       117.8     8    3
# 5          Shane Watson    214   RR  AUS  543   380       142.9    59   22
# 15       Kieron Pollard    117   MI   WI  360   249       144.6    20   26
# 17         Yuvraj Singh    274  PWI  IND  238   190       125.3    14   15
# 21        Andre Russell     24   DD   WI   11    14        78.6     0    0
# 26         Chris Morris     57  CSK  IND   14    15        93.3     0    0
# 28        Vijay Shankar    250  CSK  IND    0     0           -     0    0
# 31           Axar Patel     15   MI  IND    0     0           -     0    0
# 33         Jalaj Saxena     98   MI  IND    0     0           -     0    0
# 38         Yusuf Pathan    273  KKR  IND  332   240       138.3    30   14
# ...

# %%
bowl2018_2=AR2013[AR2013["Matches Played"]!=0]

# %%
bowl2018_2=bowl2018_2[bowl2018_2["Wickets"]!=0]

# %%
bowl2018_2=bowl2018_2[bowl2018_2["Run"]!=0]

# %%
bowl2018_22=bowl2018_2.drop(["Player's Name","Sl.No","Team","From","Type","Age","Ct_St"],axis=1)

# %%
bowl2018_22
# Out:
#     Run  Ball Strike Rate  Four  Six  Highest Run Scored  BallsBowled  \
# 3   201   133       151.1    17    6                  38          247
# 4   106    90       117.8     8    3                  23          351
# 5   543   380       142.9    59   22                 101          250
# 15  360   249       144.6    20   26                  66          162
# 17  238   190       125.3    14   15                  34          132
# 26   14    15        93.3     0    0                   7          276
# 38  332   240       138.3    30   14                  72           54
# 44  293   199       147.2    25   12                  41          144
# 53   26    31        83.9     4    0                  11          330
# 55  165   125         132    20    3                  44          127
#
#     RunsConceded Economy  Wickets  Run Outs  Matches Played  wickettaking2013  \
# 3            304     7.4       13       1.5              17         19.000000
# ...

# %%
pca14 = PCA(n_components=2)

# %%
lol14=pca14.fit_transform(bowl2018_22)

# %%
lol14
# Out:
# array([[ -62.11798259,   28.85624003],
#        [-247.27660564,  133.44003939],
#        [ 306.45616436,  243.99523523],
#        [ 153.4130308 ,   52.58776184],
#        [  84.84120833, -104.29941329],
#        [-296.3592465 ,  -22.0210064 ],
#        [ 239.14019898, -147.21781923],
#        [ 123.24811742,  -64.6838881 ],
#        [-294.43481127,   11.77472543],
#        [  -6.91007389, -132.4318749 ]])

# %%
print(pca1.singular_values_)
# Out:
# [1029.52335598  149.04507131]

# %%
print(pca.singular_values_)
# Out:
# [1380.75130978  142.70229536]

# %%
data
# Out:
#              0          1
# 0  -216.493609 -25.899136
# 1   164.898539   7.826118
# 2    60.418502  32.046105
# 3    89.565564  -4.708752
# 4   192.489224 -26.083746
# 5   266.165246  21.394502
# 6  -228.438647   2.038629
# 7   300.236505 -41.287044
# 8  -142.766086 -16.432217
# 9   166.953711 -15.794091
# 10  241.879623  25.668621
# 11  -84.800153  -8.782218
# 12  119.771518  -6.107104
# 13 -178.883859   7.461656
# 14  114.230138 -19.905660
# 15 -267.216863  10.329406
# 16 -250.934749   4.139959
# 17  -72.842027  -8.696877
# 18  -41.741430 -18.739824
# 19 -140.305530  19.385424
# 20 -273.467245  17.811657
# 21  199.809829 -41.476981
# 22  184.571510  34.650892
# 23 -162.975835 -17.471304
# 24  191.584733  -5.354999
# 25   68.891793  -2.340877
# 26 -215.390450  -2.893592
# 27  181.356269  43.967337
# 28  -94.423931 -22.980526
# 29  123.524296  32.736535
# 30  -97.419019   3.023607
# 31 -110.984280  25.221214
# 32 -163.946418   6.218968
# 33  123.375091  10.836188
# ...

# %%
data=pd.DataFrame(lol14)

# %%
bowl2018_2.reset_index(drop=True,inplace=True)

# %%
data["Name"]=bowl2018_2["Player\'s Name"]

# %%
data
# Out:
#             0           1                 Name
# 0  -62.117983   28.856240      Ravindra Jadeja
# 1 -247.276606  133.440039         Dwayne Bravo
# 2  306.456164  243.995235         Shane Watson
# 3  153.413031   52.587762       Kieron Pollard
# 4   84.841208 -104.299413         Yuvraj Singh
# 5 -296.359246  -22.021006         Chris Morris
# 6  239.140199 -147.217819         Yusuf Pathan
# 7  123.248117  -64.683888         Stuart Binny
# 8 -294.434811   11.774725  Ravichandran Ashwin
# 9   -6.910074 -132.431875     Moises Henriques

# %%
data.to_csv("2013AR.csv")

# %%
bowl2017
# Out:
#             Player's Name  Sl.no Team From  Balls Bowled  Runs Conceded  \
# 2           Deepak Chahar     51  RPS  IND            42             74
# 9             Imran Tahir     68  RPS   SA           282            369
# 12        Harbhajan Singh     64   MI  IND           246            266
# 13         Shardul Thakur    173  RPS  IND           229            315
# 14           Mohit Sharma    118  KXI  IND           274            410
# 17         Jasprit Bumrah     78   MI  IND           356            440
# 21           Rahul Chahar    144  RPS  IND            42             58
# 27   Mitchell McClenaghan    114   MI   NZ           324            507
# 28             Adam Milne      4  RCB   NZ            84            134
# 29         Lasith Malinga     97   MI   SL           269            382
# 30          Barinder Sran     27   SH  IND            12             29
# 35           Sunil Narine    188  KKR   WI           354            412
# ...

# %%
bowl2018
# Out:
#             Player's Name  Sl.No Team From  Balls  Bowled  Runs Scored  \
# 2           Deepak Chahar     50  CSK  IND            229          278
# 3                 KM Asif     21  CSK  IND             36           75
# 14            Lungi Ngidi     96  CSK   SA            156          156
# 15            Imran Tahir     67  CSK   SA            124          188
# 18        Harbhajan Singh     63  CSK  IND            191          270
# 19         Shardul Thakur    167  CSK  IND            280          431
# 20             Monu Kumar    123  CSK  IND              0            0
# 22           Mohit Sharma    121  KXI  IND            178          322
# 25         Jasprit Bumrah     74   MI  IND            324          372
# 29        Mayank Markande    109   MI  IND            264          368
# 30           Rahul Chahar    145   MI  IND              0            0
# 38   Mitchell McClenaghan    114   MI   NZ            240          332
# ...

# %%
AR2018
# Out:
#            Player's Name  Sl.No Team From  Run  Ball Strike Rate  4's  6's  \
# 4            Karn Sharma     86  CSK  IND    0     0           -    0    0
# 5           Dhruv Shorey     53  CSK  IND    8     9        88.9    0    1
# 8        Ravindra Jadeja    149  CSK  IND   89    74       120.3    3    4
# 10      Mitchell Santner    115  CSK   NZ    0     0           -    0    0
# 12          Dwayne Bravo     56  CSK   WI  141    91       154.9    8   10
# 13          Shane Watson    165  CSK  AUS  555   359       154.6   44   35
# 21     Chaitanya Bishnoi     36  CSK  IND    0     0           -    0    0
# 24         Hardik Pandya     64   MI  IND  260   195       133.3   20   11
# 26         Krunal Pandya     91   MI  IND  228   157       145.2   22   10
# 31            Anukul Roy     17   MI  IND    0     0           -    0    0
# 36        Kieron Pollard     89   MI   WI  133   100         133   10    7
# ...
